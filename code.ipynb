# %%
2+3
# Out:
# 5

# %%
2-3
# Out:
# -1

# %%
3*3
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
(2+3)-8
# Out:
# -3

# %%
10/2
# Out:
# 5.0

# %%
10//2

# %%
'Welcome to Gen AI with Agentic AI'
# Out:
# 'Welcome to Gen AI with Agentic AI'
